# %%
import pandas as pd
df =pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/happy2/happiness.csv',encoding='utf-8')
df.head()
# Out:
#    행복랭킹          나라명     점수  상대GDP  사회적지원  행복기대치  선택의 자유도    관대함  부패에 대한인식  \
# 0     1      Finland  7.769  1.340  1.587  0.986    0.596  0.153     0.393
# 1     2      Denmark  7.600  1.383  1.573  0.996    0.592  0.252     0.410
# 2     3       Norway  7.554  1.488  1.582  1.028    0.603  0.271     0.341
# 3     4      Iceland  7.494  1.380  1.624  1.026    0.591  0.354     0.118
# 4     5  Netherlands  7.488  1.396  1.522  0.999    0.557  0.322     0.298
#
#      년도
# 0  2019
# 1  2019
# 2  2019
# 3  2019
# 4  2019

# %%
df[df['행복랭킹'] == 10].점수.mean()
# Out:
# 7.259

# %%
df[df['행복랭킹'] <= 50][['년도','점수']].groupby('년도').mean()
# Out:
#            점수
# 년도
# 2018  6.64678
# 2019  6.67002

# %%
df[df['년도'] == 2018][['점수','부패에 대한인식']].corr().iloc[0,1]
# Out:
# 0.40529152271510027

# %%
len(df[['행복랭킹','나라명']]) - len(df[['행복랭킹','나라명']].drop_duplicates())
# Out:
# 15

# %%
test=df[df.년도==2019][['행복기대치','상대GDP','사회적지원','점수']].corr().unstack().to_frame().reset_index()
test=test.sort_values(0,ascending=False).drop_duplicates(0).head(5).reset_index(drop=True)
test.columns=['v1','v2','corr']
test
# Out:
#       v1     v2      corr
# 0  행복기대치  행복기대치  1.000000
# 1  행복기대치  상대GDP  0.835462
# 2  상대GDP     점수  0.793883
# 3  행복기대치     점수  0.779883
# 4  사회적지원     점수  0.777058

# %%
df.groupby('년도').tail(5).groupby('년도').점수.mean()
# Out:
# 년도
# 2018    3.1800
# 2019    3.1408
# Name: 점수, dtype: float64

# %%
df2019 = df[df['년도']==2019]

over=df[df['상대GDP'] >= df['상대GDP'].mean()].점수.mean()
under=df[df['상대GDP'] <= df['상대GDP'].mean()].점수.mean()

over-under
# Out:
# 1.4212148925537234

# %%
df.sort_values(['년도','부패에 대한인식'],ascending=False).groupby('년도').head(20).groupby('년도')['부패에 대한인식'].mean()
# Out:
# 년도
# 2018    0.3267
# 2019    0.3201
# Name: 부패에 대한인식, dtype: float64

# %%
df2018 = df[(df['년도'] ==2018) & (df['행복랭킹'] <= 50)].나라명
df2019 = df[(df['년도'] ==2019) & (df['행복랭킹'] <= 50)].나라명

len(set(df2018)-set(df2019))
# Out:
# 4

# %%
# Out:
# 나라명
# Finland      2
# Albania      2
# Nepal        2
# Jordan       2
# Benin        2
#             ..
# Gambia       1
# Belize       1
# Macedonia    1
# Sudan        1
# Angola       1
# Name: count, Length: 160, dtype: int64
